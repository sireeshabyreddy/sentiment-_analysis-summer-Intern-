# %%
import pandas as pd

# %%
data=pd.read_csv("Reviews.csv")

# %%
data
# Out:
#                                                 Review  Liked
# 0                             Wow... Loved this place.      1
# 1                                   Crust is not good.      0
# 2            Not tasty and the texture was just nasty.      0
# 3    Stopped by during the late May bank holiday of...      1
# 4    The selection on the menu was great and so wer...      1
# ..                                                 ...    ...
# 995  I think food should have flavor and texture an...      0
# 996                           Appetite instantly gone.      0
# 997  Overall I was not impressed and would not go b...      0
# 998  The whole experience was underwhelming, and I ...      0
# 999  Then, as if I hadn't wasted enough of my life ...      0
#
# [1000 rows x 2 columns]

# %%
data.head()
# Out:
#                                               Review  Liked
# 0                           Wow... Loved this place.      1
# 1                                 Crust is not good.      0
# 2          Not tasty and the texture was just nasty.      0
# 3  Stopped by during the late May bank holiday of...      1
# 4  The selection on the menu was great and so wer...      1

# %%
data.head(20)
# Out:
#                                                Review  Liked
# 0                            Wow... Loved this place.      1
# 1                                  Crust is not good.      0
# 2           Not tasty and the texture was just nasty.      0
# 3   Stopped by during the late May bank holiday of...      1
# 4   The selection on the menu was great and so wer...      1
# 5      Now I am getting angry and I want my damn pho.      0
# 6               Honeslty it didn't taste THAT fresh.)      0
# 7   The potatoes were like rubber and you could te...      0
# 8                           The fries were great too.      1
# 9                                      A great touch.      1
# 10                           Service was very prompt.      1
# 11                                 Would not go back.      0
# 12  The cashier had no care what so ever on what I...      0
# 13  I tried the Cape Cod ravoli, chicken, with cra...      1
# ...

# %%
data.tail()
# Out:
#                                                 Review  Liked
# 995  I think food should have flavor and texture an...      0
# 996                           Appetite instantly gone.      0
# 997  Overall I was not impressed and would not go b...      0
# 998  The whole experience was underwhelming, and I ...      0
# 999  Then, as if I hadn't wasted enough of my life ...      0

# %%
data.tail(15)
# Out:
#                                                 Review  Liked
# 985  The problem I have is that they charge $11.99 ...      0
# 986  Shrimp- When I unwrapped it (I live only 1/2 a...      0
# 987     It lacked flavor, seemed undercooked, and dry.      0
# 988  It really is impressive that the place hasn't ...      0
# 989  I would avoid this place if you are staying in...      0
# 990  The refried beans that came with my meal were ...      0
# 991         Spend your money and time some place else.      0
# 992  A lady at the table next to us found a live gr...      0
# 993            the presentation of the food was awful.      0
# 994           I can't tell you how disappointed I was.      0
# 995  I think food should have flavor and texture an...      0
# 996                           Appetite instantly gone.      0
# 997  Overall I was not impressed and would not go b...      0
# 998  The whole experience was underwhelming, and I ...      0
# ...

# %%
data.shape  #output is a tuple
# Out:
# (1000, 2)

# %%
data.shape[0] # To access the number of rows in a dataset
# Out:
# 1000

# %%
data.shape[1] # To access the number of columns in a dataset
# Out:
# 2

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 2 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   Review  1000 non-null   object
#  1   Liked   1000 non-null   int64
# dtypes: int64(1), object(1)
# memory usage: 15.8+ KB

# %%
data.describe().T  #gives only numerical cols valuesdf.drop_duplicates()
# Out:
#         count  mean      std  min  25%  50%  75%  max
# Liked  1000.0   0.5  0.50025  0.0  0.0  0.5  1.0  1.0

# %%
data.describe(include="all").T  #here T is for transpose
# Out:
#          count unique     top freq mean      std  min  25%  50%  75%  max
# Review    1000    993  #NAME?    4  NaN      NaN  NaN  NaN  NaN  NaN  NaN
# Liked   1000.0    NaN     NaN  NaN  0.5  0.50025  0.0  0.0  0.5  1.0  1.0

# %%
data.describe(include="object").T   #for only categorical columns
# Out:
#        count unique     top freq
# Review  1000    993  #NAME?    4

# %%
data.duplicated().sum()   #if no null  values in dataset  then it gives output 0.
# Out:
# 6

# %%
data.drop_duplicates(inplace=True)

# %%
data.isnull()
# Out:
#      Review  Liked
# 0     False  False
# 1     False  False
# 2     False  False
# 3     False  False
# 4     False  False
# ..      ...    ...
# 995   False  False
# 996   False  False
# 997   False  False
# 998   False  False
# 999   False  False
#
# [994 rows x 2 columns]

# %%
data.isnull().sum()  #gives the no of null vaues row wise
# Out:
# Review    0
# Liked     0
# dtype: int64

# %%
data.dtypes   #  gives each column wise datatypes
# Out:
# Review    object
# Liked      int64
# dtype: object

# %%
data.columns  # gives all column names
# Out:
# Index(['Review', 'Liked'], dtype='object')

# %%
data['Liked'].unique()   # To know all unique values of column named "Liked" in a dataset
# Out:
# array([1, 0])

# %%
import seaborn as sns
import matplotlib.pyplot as plt
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[22], line 1
# ----> 1 import seaborn as sns
#       2 import matplotlib.pyplot as plt
#
# ModuleNotFoundError: No module named 'seaborn'

# %%
from wordcloud import WordCloud

# %%
combined_text = " ".join(data['Review']) #combine all review text into one string

# %%
wordcloud = WordCloud(width=800 ,height = 400 ,background_color = 'white').generate(combined_text)

# %%
#plot the word cloud
plt.figure(figsize=(10,6))
plt.imshow(wordcloud,interpolation = 'bicubic')

# %%
#plot the word cloud
plt.figure(figsize=(10,6))
plt.imshow(wordcloud,interpolation = 'bicubic')
plt.axis('off')
plt.title('Word Cloud of Reviews')
plt.show()

# %%
# Uisng text blob
from textblob import TextBlob

def get_sentiment(review):
    blob = TextBlob(review)
    sentiment_score = blob.sentiment.polarity
    return sentiment_score

# Apply the function to calculate sentiment polarity for each review
data['Sentiment'] = data['Review'].apply(get_sentiment)

# Display the dataset with sentiment scores
print(data.head(20))
# Out:
#                                                Review  Liked  Sentiment
# 0                            Wow... Loved this place.      1    0.40000
# 1                                  Crust is not good.      0   -0.35000
# 2           Not tasty and the texture was just nasty.      0   -1.00000
# 3   Stopped by during the late May bank holiday of...      1    0.20000
# 4   The selection on the menu was great and so wer...      1    0.80000
# 5      Now I am getting angry and I want my damn pho.      0   -0.50000
# 6               Honeslty it didn't taste THAT fresh.)      0    0.30000
# 7   The potatoes were like rubber and you could te...      0    0.00000
# 8                           The fries were great too.      1    0.80000
# 9                                      A great touch.      1    0.80000
# 10                           Service was very prompt.      1    0.20000
# 11                                 Would not go back.      0    0.00000
# ...

# %%
data.drop(columns=['Sentiment'], inplace=True)

# %%
data
# Out:
#                                                 Review  Liked
# 0                             Wow... Loved this place.      1
# 1                                   Crust is not good.      0
# 2            Not tasty and the texture was just nasty.      0
# 3    Stopped by during the late May bank holiday of...      1
# 4    The selection on the menu was great and so wer...      1
# ..                                                 ...    ...
# 995  I think food should have flavor and texture an...      0
# 996                           Appetite instantly gone.      0
# 997  Overall I was not impressed and would not go b...      0
# 998  The whole experience was underwhelming, and I ...      0
# 999  Then, as if I hadn't wasted enough of my life ...      0
#
# [994 rows x 2 columns]

# %%
from nltk.tokenize import word_tokenize
from nltk.corpus import stopwords
import nltk

nltk.download('punkt')
nltk.download('stopwords')
def clean_text(text):
    text = text.lower()
    text = ''.join([char for char in text if char.isalpha() or char.isspace()])
    tokens = word_tokenize(text)
    stop_words = set(stopwords.words('english'))
    tokens = [word for word in tokens if word not in stop_words]
    return ' '.join(tokens)

# Assuming you have a DataFrame 'data' with a column 'Review'
data['Cleaned_Review'] = data['Review'].apply(clean_text)
# Out:
# [nltk_data] Downloading package punkt to /home/rgukt/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package stopwords to /home/rgukt/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!

# %%
# Count the number of positive (Liked=1) and negative (Liked=0) reviews
positive_reviews = data[data['Liked'] == 1].shape[0]
negative_reviews = data[data['Liked'] == 0].shape[0]

print("Number of positive reviews:", positive_reviews)
print("Number of negative reviews:", negative_reviews)
# Out:
# Number of positive reviews: 498
# Number of negative reviews: 496

# %%
# Count the number of positive (Liked=1) and negative (Liked=0) reviews
positive_reviews = data[data['Liked'] == 1].shape[0]
negative_reviews = data[data['Liked'] == 0].shape[0]

# Create a bar plot
plt.figure(figsize=(8, 6))
plt.bar(['Positive', 'Negative'], [positive_reviews, negative_reviews], color=['green', 'red'])
plt.xlabel('Review Sentiment')
plt.ylabel('Number of Reviews')
plt.title('Distribution of Review Sentiments')
plt.show()

# %%
plt.figure(figsize=(8, 6))
labels = ['Positive', 'Negative']
sizes = [positive_reviews, negative_reviews]
colors = ['lightgreen', 'lightcoral']
plt.pie(sizes, labels=labels, colors=colors, autopct='%1.1f%%', startangle=140)
plt.axis('equal')
plt.title('Distribution of Positive and Negative Reviews')
plt.show()

# %%
data
# Out:
#                                                 Review  Liked  \
# 0                             Wow... Loved this place.      1
# 1                                   Crust is not good.      0
# 2            Not tasty and the texture was just nasty.      0
# 3    Stopped by during the late May bank holiday of...      1
# 4    The selection on the menu was great and so wer...      1
# ..                                                 ...    ...
# 995  I think food should have flavor and texture an...      0
# 996                           Appetite instantly gone.      0
# 997  Overall I was not impressed and would not go b...      0
# 998  The whole experience was underwhelming, and I ...      0
# 999  Then, as if I hadn't wasted enough of my life ...      0
#
#                                         Cleaned_Review
# 0                                      wow loved place
# 1                                           crust good
# ...

# %%
data['Review_Length'] = data['Review'].apply(len)
plt.figure(figsize=(8, 6))
sns.boxplot(x='Liked', y='Review_Length', data=data)
plt.title('Distribution of Review Lengths by Sentiment')
plt.xlabel('Sentiment')
plt.ylabel('Review Length')
plt.show()

# %%
data
# Out:
#                                                 Review  Liked  \
# 0                             Wow... Loved this place.      1
# 1                                   Crust is not good.      0
# 2            Not tasty and the texture was just nasty.      0
# 3    Stopped by during the late May bank holiday of...      1
# 4    The selection on the menu was great and so wer...      1
# ..                                                 ...    ...
# 995  I think food should have flavor and texture an...      0
# 996                           Appetite instantly gone.      0
# 997  Overall I was not impressed and would not go b...      0
# 998  The whole experience was underwhelming, and I ...      0
# 999  Then, as if I hadn't wasted enough of my life ...      0
#
#                                         Cleaned_Review  Review_Length
# 0                                      wow loved place             24
# 1                                           crust good             18
# ...

# %%
plt.figure(figsize=(8, 6))
sns.histplot(data=data, x='Review_Length', hue='Liked', kde=True, bins=30)
plt.title('Distribution of Review Lengths by Sentiment')
plt.xlabel('Review Length')
plt.ylabel('Frequency')
plt.show()

# %%
plt.figure(figsize=(8, 6))
sns.scatterplot(data=data, x='Review_Length', y='Liked')
plt.title('Scatter Plot of Review Lengths by Sentiment')
plt.xlabel('Review Length')
plt.ylabel('Sentiment')
plt.show()

# %%
from scipy import stats

z_scores = stats.zscore(data['Review_Length'])
outliers = (z_scores > 3) | (z_scores < -3)
outlier_indices = data.index[outliers]
print("Indices of outliers:", outlier_indices)
# Out:
# Indices of outliers: Int64Index([], dtype='int64')

# %%
import nltk
from nltk.corpus import stopwords
from nltk.tokenize import word_tokenize
from nltk.stem import PorterStemmer

# %%
data.head()
# Out:
#                                               Review  Liked  \
# 0                           Wow... Loved this place.      1
# 1                                 Crust is not good.      0
# 2          Not tasty and the texture was just nasty.      0
# 3  Stopped by during the late May bank holiday of...      1
# 4  The selection on the menu was great and so wer...      1
#
#                                       Cleaned_Review  Review_Length
# 0                                    wow loved place             24
# 1                                         crust good             18
# 2                                tasty texture nasty             41
# 3  stopped late may bank holiday rick steve recom...             87
# 4                        selection menu great prices             59

# %%
#(1)

import matplotlib.pyplot as plt
from wordcloud import WordCloud
import seaborn as sns
from sklearn.model_selection import train_test_split
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.naive_bayes import MultinomialNB
from sklearn.metrics import accuracy_score, confusion_matrix, classification_report

X_train, X_test, y_train, y_test = train_test_split(data['Cleaned_Review'], data['Liked'], test_size=0.15, random_state=42)

# Vectorize text data
vectorizer = TfidfVectorizer(max_features=5000)
X_train_tfidf = vectorizer.fit_transform(X_train)
X_test_tfidf = vectorizer.transform(X_test)

# Train a Naive Bayes classifier
nb_classifier = MultinomialNB()
nb_classifier.fit(X_train_tfidf, y_train)

# Predict and evaluate the model
y_pred = nb_classifier.predict(X_test_tfidf)
accuracy = accuracy_score(y_test, y_pred)
conf_matrix = confusion_matrix(y_test, y_pred)
class_report = classification_report(y_test, y_pred)

print(f"Accuracy: {accuracy}")
print("Confusion Matrix:")
print(conf_matrix)
print("Classification Report:")
print(class_report)
# Out:
# Accuracy: 0.78
# Confusion Matrix:
# [[54 22]
#  [11 63]]
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.83      0.71      0.77        76
#            1       0.74      0.85      0.79        74
#
#     accuracy                           0.78       150
#    macro avg       0.79      0.78      0.78       150
# weighted avg       0.79      0.78      0.78       150

# %%
#(2)

from sklearn.feature_extraction.text import CountVectorizer
from sklearn.naive_bayes import MultinomialNB
from sklearn.pipeline import Pipeline

# The pipeline with CountVectorizer and Multinomial Naive Bayes classifier

pipeline = Pipeline([
    ('vectorizer', CountVectorizer()), 
    ('classifier', MultinomialNB())  
])
# Fit the pipeline on the training data
pipeline.fit(X_train, y_train)

# Predict on the testing data
y_pred = pipeline.predict(X_test)

# Evaluate the accuracy
accuracy = accuracy_score(y_test, y_pred)
print("Accuracy:", accuracy)
# Out:
# Accuracy: 0.78

# %%
#(3)

from sklearn.svm import SVC

# Train a Support Vector Machine (SVM) classifier
svm_classifier = SVC(kernel='linear')
svm_classifier.fit(X_train_tfidf, y_train)

# Predict using the SVM classifier
y_pred_svm = svm_classifier.predict(X_test_tfidf)

# Evaluate the SVM model
accuracy_svm = accuracy_score(y_test, y_pred_svm)
conf_matrix_svm = confusion_matrix(y_test, y_pred_svm)
class_report_svm = classification_report(y_test, y_pred_svm)

print(f"SVM Classifier Accuracy: {accuracy_svm}")
print("SVM Classifier Confusion Matrix:")
print(conf_matrix_svm)
print("SVM Classifier Classification Report:")
print(class_report_svm)
# Out:
# SVM Classifier Accuracy: 0.8
# SVM Classifier Confusion Matrix:
# [[64 12]
#  [18 56]]
# SVM Classifier Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.78      0.84      0.81        76
#            1       0.82      0.76      0.79        74
#
#     accuracy                           0.80       150
#    macro avg       0.80      0.80      0.80       150
# weighted avg       0.80      0.80      0.80       150

# %%
#(4)

# The pipeline with CountVectorizer and SVM classifier
pipeline = Pipeline([
    ('vectorizer', CountVectorizer()),  
    ('classifier', SVC(kernel='linear')) 
])
# Fit the pipeline on the training data
pipeline.fit(X_train, y_train)

# Predict on the testing data
y_pred = pipeline.predict(X_test)

# Evaluate the accuracy
accuracy = accuracy_score(y_test, y_pred)
print("Accuracy:", accuracy)
# Out:
# Accuracy: 0.8066666666666666

# %%
conf_matrix = confusion_matrix(y_test, y_pred)

# Plot confusion matrix
plt.figure(figsize=(8, 6))
sns.heatmap(conf_matrix, annot=True, fmt='d', cmap='Blues', cbar=False)
plt.xlabel('Predicted')
plt.ylabel('Actual')
plt.title('Confusion Matrix')
plt.savefig('conf_matrix.png', bbox_inches='tight')
plt.show()

# %%
# Test function
def predict_sentiment(review):
    processed_review = clean_text(review)
    prediction = pipeline.predict([processed_review])
    return 'Positive' if prediction[0] == 1 else 'Negative'

example_reviews = [
   "The food was absolutely wonderful, from preparation to presentation, very pleasing.",
    "The service was terrible and the food was even worse.",
    "I had a fantastic experience at this restaurant. Highly recommend it!",
    "The ambiance was great but the food was just okay.",
    "I will never come back to this place. Completely disappointed.",
    "An average dining experience. Nothing special but not bad either.",
    "Loved the desserts! They were the highlight of our meal.",
    "Horrible experience. Will not be returning.",
    "Amazing flavors and great service. Will definitely visit again.",
    "Not worth the price. The food lacked flavor and was overpriced."
]

# Predict sentiment for the example reviews
for review in example_reviews:
    sentiment = predict_sentiment(review)
    print(f"Review: {review}\nPredicted Sentiment: {sentiment}\n")
# Out:
# Review: The food was absolutely wonderful, from preparation to presentation, very pleasing.
# Predicted Sentiment: Positive
#
# Review: The service was terrible and the food was even worse.
# Predicted Sentiment: Negative
#
# Review: I had a fantastic experience at this restaurant. Highly recommend it!
# Predicted Sentiment: Positive
#
# Review: The ambiance was great but the food was just okay.
# Predicted Sentiment: Positive
#
# Review: I will never come back to this place. Completely disappointed.
# Predicted Sentiment: Negative
#
# Review: An average dining experience. Nothing special but not bad either.
# Predicted Sentiment: Negative
#
# Review: Loved the desserts! They were the highlight of our meal.
# Predicted Sentiment: Positive
#
# Review: Horrible experience. Will not be returning.
# Predicted Sentiment: Negative
#
# Review: Amazing flavors and great service. Will definitely visit again.
# Predicted Sentiment: Positive
#
# ...
